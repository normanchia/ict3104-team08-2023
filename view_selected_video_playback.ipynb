# %%
# to replace with user selections
selected_input_file_name = "dancing_example_1.mp4"
input_path = f"./input_data/{selected_input_file_name}"

# to replace with generated files
generated_output_file_name = "Iron man in the beach.gif"
output_path = f"./output/{generated_output_file_name}"

# %%
from IPython.display import Video
Video(input_path, width=300, height=300)
# Out:
# <video src="./input_data/dancing_example_1.mp4" controls  width="300"  height="300">
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
from IPython.display import Image
Image(output_path, width=300, height=300)
